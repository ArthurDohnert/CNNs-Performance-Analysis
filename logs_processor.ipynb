# %%
import pandas as pd
import os
import re
from datetime import datetime
from typing import List

INVALID_FS_CHARS = r'[\\/:"*?<>|]'

def sanitize_for_fs(name: str) -> str:
    name = re.sub(INVALID_FS_CHARS, "", str(name))
    name = re.sub(r"\s+", "_", name.strip())
    return name[:128] if name else "unknown"

def ensure_dir(path: str):
    os.makedirs(path, exist_ok=True)

def parse_log_epochs_with_header(log_file_path):
    cfg = {
        "seed": None,   
        "model_name": None,
        "config_path": None,
        "train_data_path": None,
        "val_data_path": None,
        "model_params": None,
        "train_params": None,
        "inference_params": None,
        "scheduler_params": None,
    }
    config_map = {
        "Model Name": "model_name",
        "Config File": "config_path",
        "Train Data": "train_data_path",
        "Validation Data": "val_data_path",
        "model_params": "model_params",
        "train_params": "train_params",
        "inference_params": "inference_params",
        "scheduler_params": "scheduler_params",
    }

    re_epoch_done = re.compile(r"Época\s+(\d+)\s+concluída\.\s*Loss média:\s*([0-9]+\.[0-9]+|[0-9]+)", re.IGNORECASE)
    re_lr_step = re.compile(r"Taxa de aprendizado ajustada para:\s*([0-9]+\.[0-9]+|[0-9]+)", re.IGNORECASE)
    re_seed = re.compile(r"Semente aleatória para esta execução foi fixada em:\s*([0-9]+)", re.IGNORECASE)


    in_config = False
    in_results = False
    current_epoch = None
    epoch_rows = []
    results_buffer = {}

    key_alias = {
        "Elapsed Time Seconds": "elapsed_time_seconds",
        "Cpu Usage Percent": "cpu_usage_percent",
        "Ram Peak Usage Bytes": "ram_peak_bytes",
        "Disk Read Bytes": "disk_read_bytes",
        "Disk Write Bytes": "disk_write_bytes",
        "Vram Peak Usage Bytes": "vram_peak_bytes",
        "Gpu Power Watts Avg": "gpu_power_watts_avg",
        "Gpu Power Watts Peak": "gpu_power_watts_peak",
        "Gpu Temp Celsius Avg": "gpu_temp_celsius_avg",
        "Gpu Temp Celsius Peak": "gpu_temp_celsius_peak",
        "Gpu Utilization Percent Avg": "gpu_util_percent_avg",
        "Gpu Utilization Percent Peak": "gpu_util_percent_peak",
        "Gpu Mem Used Bytes Avg": "gpu_mem_used_bytes_avg",
        "Gpu Mem Used Bytes Peak": "gpu_mem_used_bytes_peak",
        "Gpu Vram Used Bytes": "gpu_vram_used_bytes",
        "Accuracy": "val_accuracy",
        "Precision": "val_precision",
        "Recall": "val_recall",
        "F1 Score": "val_f1",
    }

    with open(log_file_path, "r", encoding="utf-8") as f:
        for raw in f:
            line = raw.strip()
            if not line:
                continue

            if "EXPERIMENT CONFIGURATION" in line:
                in_config = True
                in_results = False
                continue
            if "EXPERIMENT RESULTS" in line:
                in_results = True
                continue

            if in_config:
                tail = line.split(" - INFO - ")[-1]

                m_seed = re_seed.search(tail)
                if m_seed:
                    cfg["seed"] = int(m_seed.group(1)) 
                    continue

                if ":" in tail:
                    key, val = [x.strip() for x in tail.split(":", 1)]
                    if key in config_map:
                        cfg[config_map[key]] = val

                if "Semente aleatória" in tail or "Iniciando treinamento" in tail:
                    in_config = False
                continue

            m_ep = re_epoch_done.search(line)
            if m_ep:
                if results_buffer and epoch_rows:
                    epoch_rows[-1].update(results_buffer)
                    results_buffer = {}

                current_epoch = int(m_ep.group(1))
                train_loss = float(m_ep.group(2))
                epoch_rows.append({
                    "epoch": current_epoch,
                    "train_loss": train_loss,
                    "lr": None,  
                })
                continue

            m_lr = re_lr_step.search(line)
            if m_lr and current_epoch is not None and epoch_rows:
                epoch_rows[-1]["lr"] = float(m_lr.group(1))
                continue

            if in_results:
                tail = line.split(" - INFO - ")[-1]
                if ":" in tail:
                    k, v = [x.strip() for x in tail.split(":", 1)]
                    col = key_alias.get(k)
                    if col:
                        try:
                            results_buffer[col] = float(v)
                        except:
                            pass

    if results_buffer and epoch_rows:
        epoch_rows[-1].update(results_buffer)

    lr_base = None
    tp = cfg.get("train_params")
    if tp:
        m = re.search(r"'learning_rate'\s*:\s*([0-9]+\.[0-9]+|[0-9]+)", tp)
        if m:
            lr_base = float(m.group(1))

    per_epoch_cols = [
        "epoch", "train_loss", "lr",
        "elapsed_time_seconds", "cpu_usage_percent", "ram_peak_bytes",
        "disk_read_bytes", "disk_write_bytes", "vram_peak_bytes",
        "gpu_power_watts_avg", "gpu_power_watts_peak",
        "gpu_temp_celsius_avg", "gpu_temp_celsius_peak",
        "gpu_util_percent_avg", "gpu_util_percent_peak",
        "gpu_mem_used_bytes_avg", "gpu_mem_used_bytes_peak",
        "gpu_vram_used_bytes",
        "val_accuracy", "val_precision", "val_recall", "val_f1",
    ]
    df_epochs = pd.DataFrame(epoch_rows, columns=per_epoch_cols)

    header_meta = {
        "seed": cfg.get("seed"),
        "model_name": cfg.get("model_name"),
        "config_path": cfg.get("config_path"),
        "train_data_path": cfg.get("train_data_path"),
        "val_data_path": cfg.get("val_data_path"),
        "model_params": cfg.get("model_params"),
        "train_params": cfg.get("train_params"),
        "inference_params": cfg.get("inference_params"),
        "scheduler_params": cfg.get("scheduler_params"),
        "lr_base": lr_base,
    }
    return df_epochs, header_meta

def write_csv_with_header(csv_path, header_meta, df_epochs):
    # Escrever cabeçalho em uma primeira linha, depois linhas por época
    ensure_dir(os.path.dirname(csv_path))
    header_cols = [
        "model_name","seed", "config_path","train_data_path","val_data_path",
        "model_params","train_params","inference_params","scheduler_params","lr_base"
    ]
    header_values = [header_meta.get(k, "") for k in header_cols]

    with open(csv_path, "w", encoding="utf-8") as fh:
        fh.write(",".join(header_cols) + "\n")
        def quote_if_needed(x):
            if x is None:
                return ""
            s = str(x)
            if "," in s or "{" in s or "}" in s or ":" in s or "'" in s or '"' in s or " " in s:
                return '"' + s.replace('"', '""') + '"'
            return s
        fh.write(",".join(quote_if_needed(v) for v in header_values) + "\n")

    df_epochs.to_csv(csv_path, mode="a", index=False)

def infer_model_and_run_from_name_or_meta(log_file_path, header_meta):
    model = header_meta.get("model_name")
    if not model:
        base = os.path.splitext(os.path.basename(log_file_path))[0]
        model = base.split("_")[0] if "_" in base else base
    model_name = sanitize_for_fs(model)
    run_name = sanitize_for_fs(os.path.splitext(os.path.basename(log_file_path))[0])
    return model_name, run_name

def save_log_epochs_to_csv_with_header(log_file_path, output_base_dir="logs_csv"):
    df_epochs, header_meta = parse_log_epochs_with_header(log_file_path)
    if df_epochs is None or df_epochs.empty:
        print(f"Nenhum dado por época encontrado em {log_file_path}")
        return None

    model_name, run_name = infer_model_and_run_from_name_or_meta(log_file_path, header_meta)
    out_dir = os.path.join(output_base_dir, model_name)
    ensure_dir(out_dir)
    csv_path = os.path.join(out_dir, f"{run_name}.csv")
    write_csv_with_header(csv_path, header_meta, df_epochs)
    print(f"CSV salvo em: {csv_path}")
    return csv_path


def process_all_logs_by_epoch(logs_dir: str = "logs", output_base_dir: str = "logs_csv") -> List[str]:
    """
    Lê todos os arquivos .log em `logs_dir` e salva CSVs por época em `output_base_dir/<modelo>/<run>.csv`.
    """
    if not os.path.exists(logs_dir):
        print(f"Diretório {logs_dir} não encontrado.")
        return []

    log_files = [f for f in os.listdir(logs_dir) if f.endswith(".log")]  
    if not log_files:
        print(f"Nenhum arquivo .log encontrado em {logs_dir}.")
        return []

    csv_paths = []
    for log_file in sorted(log_files):
        log_file_path = os.path.join(logs_dir, log_file)
        print(f"Processando {log_file_path}...")
        csv_path = save_log_epochs_to_csv_with_header(log_file_path, output_base_dir)
        if csv_path:
            csv_paths.append(csv_path)

    print(f"Concluído. {len(csv_paths)} CSV(s) gerados.")
    return csv_paths

# %%
csv_paths = process_all_logs_by_epoch("logs", "logs_csv")
# Out:
# Processando logs\efficientnet_b0_epochs_100_bs_384_20251101_201648.log...
# CSV salvo em: logs_csv\efficientnet_b0\efficientnet_b0_epochs_100_bs_384_20251101_201648.csv
# Processando logs\efficientnet_b0_epochs_100_bs_384_20251101_205133.log...
# CSV salvo em: logs_csv\efficientnet_b0\efficientnet_b0_epochs_100_bs_384_20251101_205133.csv
# Processando logs\efficientnet_b0_epochs_100_bs_384_20251101_211222.log...
# CSV salvo em: logs_csv\efficientnet_b0\efficientnet_b0_epochs_100_bs_384_20251101_211222.csv
# Processando logs\efficientnet_b0_epochs_100_bs_384_20251101_213733.log...
# CSV salvo em: logs_csv\efficientnet_b0\efficientnet_b0_epochs_100_bs_384_20251101_213733.csv
# Processando logs\efficientnet_b0_epochs_100_bs_384_20251101_221232.log...
# CSV salvo em: logs_csv\efficientnet_b0\efficientnet_b0_epochs_100_bs_384_20251101_221232.csv
# Processando logs\mobilenet_V1_epochs_100_bs_1024_20251101_183517.log...
# ...
