# %%
import os
import re
import csv
import glob
from datetime import datetime
from typing import List, Tuple, Dict, Optional

import pandas as pd

INVALID_FS_CHARS = r'[\\/:"*?<>|]'

def sanitize_for_fs(name: str) -> str:
    name = re.sub(INVALID_FS_CHARS, "", str(name))
    name = re.sub(r"\s+", "_", name.strip())
    return name[:128] if name else "unknown"

def ensure_dir(path: str):
    if not path:
        return
    os.makedirs(path, exist_ok=True)

# --- helpers for parsing numbers / keys ------------------------------------
_re_number = re.compile(r"[-+]?[0-9]*\.?[0-9]+(?:[eE][-+]?[0-9]+)?")

def parse_number(s: str) -> Optional[float]:
    """
    tenta extrair um número de `s` (float ou int, notação científica).
    retorna None se não conseguir.
    """
    if s is None:
        return None
    s = str(s).strip()
    if not s:
        return None
    # remover milhares (vírgulas) e espaços
    s_clean = s.replace(",", "")
    m = _re_number.search(s_clean)
    if not m:
        return None
    try:
        return float(m.group(0))
    except Exception:
        return None

def normalize_key(k: str) -> str:
    # remove pontuação, normaliza espaços, lowercase
    k = re.sub(r"[:\-]", " ", k)
    k = re.sub(r"\s+", " ", k).strip().lower()
    return k

# mapping mais robusto: padrões -> nome de coluna final
METRIC_PATTERNS = [
    (r"elapsed time", "elapsed_time_seconds"),
    (r"cpu.*usage|cpu usage", "cpu_usage_percent"),
    (r"ram.*peak", "ram_peak_bytes"),
    (r"disk read", "disk_read_bytes"),
    (r"disk write", "disk_write_bytes"),
    (r"vram.*peak|vram peak", "vram_peak_bytes"),
    (r"gpu.*power.*avg", "gpu_power_watts_avg"),
    (r"gpu.*power.*peak", "gpu_power_watts_peak"),
    (r"gpu.*temp.*avg", "gpu_temp_celsius_avg"),
    (r"gpu.*temp.*peak", "gpu_temp_celsius_peak"),
    (r"gpu.*util.*avg", "gpu_util_percent_avg"),
    (r"gpu.*util.*peak", "gpu_util_percent_peak"),
    (r"gpu.*mem.*used.*avg", "gpu_mem_used_bytes_avg"),
    (r"gpu.*mem.*used.*peak", "gpu_mem_used_bytes_peak"),
    (r"gpu.*vram.*used", "gpu_vram_used_bytes"),
    (r"\baccuracy\b", "val_accuracy"),
    (r"\bprecision\b", "val_precision"),
    (r"\brecall\b", "val_recall"),
    (r"f1", "val_f1"),
]

# padrões específicos para extrair seed / lr / epoch
re_epoch_done = re.compile(r"Época\s+(\d+)\s+concluída\.\s*Loss média:\s*([0-9]+\.[0-9]+|[0-9]+)", re.IGNORECASE)
re_lr_step = re.compile(r"Taxa de aprendizado ajustada para:\s*([0-9]+\.[0-9]+|[0-9]+(?:e[-+]?\d+)?)", re.IGNORECASE)
re_seed = re.compile(r"Semente aleatória .*?fixada em:\s*([0-9]+)", re.IGNORECASE)

def map_metric_key(raw_key: str) -> Optional[str]:
    nk = normalize_key(raw_key)
    # primeira tentativa: correspondência por prefixos exatos conhecidos
    for pat, col in METRIC_PATTERNS:
        if re.search(pat, nk):
            return col
    return None

def _parse_timestamp_from_line(line: str) -> Optional[datetime]:
    """
    Extrai o timestamp do início da linha de log.
    Formato esperado: 'YYYY-MM-DD HH:MM:SS,mmm - INFO - ...'
    Retorna None se não conseguir parsear.
    """
    try:
        head = line.split(" - INFO - ")[0].strip()
        # normal case: "2025-11-21 13:01:09,568"
        return datetime.strptime(head, "%Y-%m-%d %H:%M:%S,%f")
    except Exception:
        # tentativa alternativa — mais permissiva (sem micros)
        try:
            return datetime.strptime(head, "%Y-%m-%d %H:%M:%S")
        except Exception:
            return None

# --- parser principal ------------------------------------------------------
def parse_log_epochs_with_header(log_file_path: str) -> Tuple[pd.DataFrame, Dict]:
    """
    Versão estendida que também estima training_time_seconds por epoch
    usando timestamps do log (excluindo a janela de inferência).
    Retorna df_epochs (inclui training_time_seconds e inference_time_seconds)
    e header_meta (como antes).
    """
    cfg = {
        "seed": None,
        "model_name": None,
        "config_path": None,
        "train_data_path": None,
        "val_data_path": None,
        "model_params": None,
        "train_params": None,
        "inference_params": None,
        "scheduler_params": None,
    }
    config_map = {
        "model name": "model_name",
        "config file": "config_path",
        "train data": "train_data_path",
        "validation data": "val_data_path",
        "model_params": "model_params",
        "train_params": "train_params",
        "inference_params": "inference_params",
        "scheduler_params": "scheduler_params",
    }

    in_config = False
    in_results = False
    current_epoch = None
    epoch_rows: List[Dict] = []
    results_buffer: Dict[str, float] = {}

    # timestamps helpers
    training_start_ts: Optional[datetime] = None
    last_inference_end_ts: Optional[datetime] = None
    current_inference_start_ts: Optional[datetime] = None

    with open(log_file_path, "r", encoding="utf-8") as f:
        for raw in f:
            line = raw.rstrip("\n")
            if not line.strip():
                continue

            ts = _parse_timestamp_from_line(line)

            # detectar blocos
            if "EXPERIMENT CONFIGURATION" in line:
                in_config = True
                in_results = False
                continue
            if "EXPERIMENT RESULTS" in line:
                in_results = True
                # the EXPERIMENT RESULTS line itself is considered the inference end timestamp
                # we'll use ts as inference_end_ts for the current epoch (if exists)
                inference_end_ts = ts
                # if we have a current epoch, associate these timestamps and compute durations
                if epoch_rows:
                    # assign inference start/end to last epoch (the epoch that just ran)
                    last = epoch_rows[-1]
                    # assign if we have a recorded start
                    if current_inference_start_ts is not None:
                        last["inference_start_ts"] = current_inference_start_ts
                        last["inference_end_ts"]   = inference_end_ts
                        # inference duration
                        try:
                            last["inference_time_seconds"] = (inference_end_ts - current_inference_start_ts).total_seconds()
                        except Exception:
                            last["inference_time_seconds"] = pd.NA
                    else:
                        # fallback: try to use elapsed_time_seconds if present later in results_buffer
                        last["inference_start_ts"] = pd.NA
                        last["inference_end_ts"] = inference_end_ts
                        last["inference_time_seconds"] = pd.NA

                    # compute training time: for first epoch, from training_start_ts -> inference_start
                    # for subsequent, from previous inference_end -> current inference_start
                    if current_inference_start_ts is not None:
                        if last_inference_end_ts is None:
                            # first epoch
                            if training_start_ts is not None:
                                try:
                                    last["training_time_seconds"] = (current_inference_start_ts - training_start_ts).total_seconds()
                                except Exception:
                                    last["training_time_seconds"] = pd.NA
                            else:
                                last["training_time_seconds"] = pd.NA
                        else:
                            try:
                                last["training_time_seconds"] = (current_inference_start_ts - last_inference_end_ts).total_seconds()
                            except Exception:
                                last["training_time_seconds"] = pd.NA
                    else:
                        last["training_time_seconds"] = pd.NA

                    # update last_inference_end_ts for next epoch
                    last_inference_end_ts = inference_end_ts

                # When entering RESULTS we expect to read metric lines next that will populate results_buffer.
                # keep results_buffer empty and let in_results handler fill it.
                results_buffer = {}
                continue

            # parse do bloco de configuração (header)
            if in_config:
                tail = line.split(" - INFO - ")[-1]
                # seed
                m_seed = re_seed.search(tail)
                if m_seed:
                    cfg["seed"] = int(m_seed.group(1))
                    continue

                if ":" in tail:
                    key, val = [x.strip() for x in tail.split(":", 1)]
                    k_norm = key.strip().lower()
                    if k_norm in config_map:
                        cfg[config_map[k_norm]] = val
                # record training start if found
                if "Iniciando treinamento" in tail:
                    # use the timestamp of this line
                    training_start_ts = ts or training_start_ts
                    in_config = False
                # sair do config a partir de sinais óbvios
                if "Semente aleatória" in tail:
                    # don't necessarily exit here—keep reading config lines
                    pass
                continue

            # detectar final de época (Ex: "Época 1 concluída. Loss média: 5.1538")
            m_ep = re_epoch_done.search(line)
            if m_ep:
                # se houver results_buffer de uma iteração anterior, aplica nos dados da epoch anterior
                if results_buffer and epoch_rows:
                    epoch_rows[-1].update(results_buffer)
                    results_buffer = {}

                current_epoch = int(m_ep.group(1))
                train_loss = parse_number(m_ep.group(2))
                # record epoch end timestamp
                epoch_rows.append({
                    "epoch": current_epoch,
                    "train_loss": train_loss,
                    "lr": None,
                    "epoch_ts": ts
                })
                continue

            # taxa de aprendizado anunciada logo após epoch
            m_lr = re_lr_step.search(line)
            if m_lr and current_epoch is not None and epoch_rows:
                lr_val = parse_number(m_lr.group(1))
                if lr_val is not None:
                    epoch_rows[-1]["lr"] = lr_val
                continue

            # detect "Iniciando inferência" -> mark the inference start timestamp for the upcoming EXPERIMENT RESULTS
            if "Iniciando inferência" in line or "Starting inference" in line:
                # store current inference start timestamp
                current_inference_start_ts = ts
                # sometimes this line also contains model name text; continue
                continue

            # parse do bloco de resultados (cada linha com "Key : value")
            if in_results:
                tail = line.split(" - INFO - ")[-1]
                # end of results block detection: if we meet a line of === or next epoch; but we handle at next epoch or EOF
                if ":" in tail:
                    k, v = [x.strip() for x in tail.split(":", 1)]
                    mapped = map_metric_key(k)
                    if mapped:
                        num = parse_number(v)
                        if num is not None:
                            results_buffer[mapped] = num
                # else ignore lines without colon
                # continue in in_results until next block/epoch
                continue

    # final: attach any remaining results_buffer to last epoch
    if results_buffer and epoch_rows:
        epoch_rows[-1].update(results_buffer)
        results_buffer = {}

    # post-process epoch_rows -> ensure inference_time_seconds exists (fallback to elapsed_time_seconds)
    for row in epoch_rows:
        # inference_time_seconds may be missing; try to fill from elapsed_time_seconds column if present
        if ("inference_time_seconds" not in row or pd.isna(row.get("inference_time_seconds"))):
            if row.get("elapsed_time_seconds") not in (None, pd.NA):
                try:
                    row["inference_time_seconds"] = float(row.get("elapsed_time_seconds"))
                except Exception:
                    row["inference_time_seconds"] = pd.NA
        # if training_time_seconds missing, leave as NaN (we prefer NaN than wrong guess)
        if "training_time_seconds" not in row:
            row["training_time_seconds"] = pd.NA

    # tentar extrair lr_base do train_params (string)
    lr_base = None
    tp = cfg.get("train_params")
    if tp:
        try:
            m = re.search(r"['\"]?learning_rate['\"]?\s*[:=]\s*([0-9]*\.?[0-9]+(?:[eE][-+]?\d+)?)", str(tp))
            if m:
                lr_base = float(m.group(1))
        except Exception:
            lr_base = None

    per_epoch_cols = [
        "epoch", "train_loss", "lr",
        "epoch_ts",
        "training_time_seconds",     # NEW: training time estimated from timestamps
        "inference_time_seconds",    # NEW: inference time (should match Elapsed Time Seconds)
        "elapsed_time_seconds", "cpu_usage_percent", "ram_peak_bytes",
        "disk_read_bytes", "disk_write_bytes", "vram_peak_bytes",
        "gpu_power_watts_avg", "gpu_power_watts_peak",
        "gpu_temp_celsius_avg", "gpu_temp_celsius_peak",
        "gpu_util_percent_avg", "gpu_util_percent_peak",
        "gpu_mem_used_bytes_avg", "gpu_mem_used_bytes_peak",
        "gpu_vram_used_bytes",
        "val_accuracy", "val_precision", "val_recall", "val_f1",
    ]

    df_epochs = pd.DataFrame(epoch_rows)
    # garante que as colunas estejam na ordem desejada (preenche com NaN se faltar)
    for c in per_epoch_cols:
        if c not in df_epochs.columns:
            df_epochs[c] = pd.NA
    df_epochs = df_epochs[per_epoch_cols]

    header_meta = {
        "seed": cfg.get("seed"),
        "model_name": cfg.get("model_name"),
        "config_path": cfg.get("config_path"),
        "train_data_path": cfg.get("train_data_path"),
        "val_data_path": cfg.get("val_data_path"),
        "model_params": cfg.get("model_params"),
        "train_params": cfg.get("train_params"),
        "inference_params": cfg.get("inference_params"),
        "scheduler_params": cfg.get("scheduler_params"),
        "lr_base": lr_base,
    }

    return df_epochs, header_meta

# --- CSV / gravação -------------------------------------------------------
def write_csv_with_header(csv_path: str, header_meta: Dict, df_epochs: pd.DataFrame):
    ensure_dir(os.path.dirname(csv_path))
    header_cols = [
        "model_name", "seed", "config_path", "train_data_path", "val_data_path",
        "model_params", "train_params", "inference_params", "scheduler_params", "lr_base"
    ]
    header_values = [header_meta.get(k, "") for k in header_cols]

    def quote_if_needed(x):
        if x is None or (isinstance(x, float) and pd.isna(x)):
            return ""
        s = str(x)
        if any(ch in s for ch in [",", "{", "}", ":", "'", '"', " "]):
            return '"' + s.replace('"', '""') + '"'
        return s

    with open(csv_path, "w", encoding="utf-8") as fh:
        fh.write(",".join(header_cols) + "\n")
        fh.write(",".join(quote_if_needed(v) for v in header_values) + "\n")

    # append dataframe (sem header)
    df_epochs.to_csv(csv_path, mode="a", index=False)

def infer_model_and_run_from_name_or_meta(log_file_path: str, header_meta: Dict) -> Tuple[str, str]:
    model = header_meta.get("model_name")
    if not model:
        base = os.path.splitext(os.path.basename(log_file_path))[0]
        model = base.split("_")[0] if "_" in base else base
    model_name = sanitize_for_fs(model)
    run_name = sanitize_for_fs(os.path.splitext(os.path.basename(log_file_path))[0])
    return model_name, run_name

def save_log_epochs_to_csv_with_header(log_file_path: str, output_base_dir: str = "logs_csv") -> Optional[str]:
    df_epochs, header_meta = parse_log_epochs_with_header(log_file_path)
    if df_epochs is None or df_epochs.empty:
        print(f"Nenhum dado por época encontrado em {log_file_path}")
        return None
    model_name, run_name = infer_model_and_run_from_name_or_meta(log_file_path, header_meta)
    out_dir = os.path.join(output_base_dir, model_name)
    ensure_dir(out_dir)
    csv_path = os.path.join(out_dir, f"{run_name}.csv")
    write_csv_with_header(csv_path, header_meta, df_epochs)
    print(f"CSV salvo em: {csv_path}")
    return csv_path

def process_all_logs_by_epoch(logs_dir: str = "logs", output_base_dir: str = "logs_csv") -> List[str]:
    """
    Lê todos os arquivos .log em logs_dir e salva CSVs por época em output_base_dir/<modelo>/<run>.csv.
    """
    if not os.path.exists(logs_dir):
        print(f"Diretório {logs_dir} não encontrado.")
        return []
    log_files = [f for f in os.listdir(logs_dir) if f.endswith(".log")]
    if not log_files:
        print(f"Nenhum arquivo .log encontrado em {logs_dir}.")
        return []

    csv_paths = []
    for log_file in sorted(log_files):
        log_file_path = os.path.join(logs_dir, log_file)
        print(f"Processando {log_file_path}...")
        csv_path = save_log_epochs_to_csv_with_header(log_file_path, output_base_dir)
        if csv_path:
            csv_paths.append(csv_path)

    print(f"Concluído. {len(csv_paths)} CSV(s) gerados.")
    return csv_paths

def split_csv_metadata_and_logs(root_dir="logs_csv"):
    """
    Percorre todas as subpastas dentro de root_dir,
    pega cada CSV e separa:
    - as 2 primeiras linhas → arquivo *_metadata.csv
    - o restante → sobrescreve o arquivo original
    """
    
    for subdir, _, _ in os.walk(root_dir):
        csv_files = glob.glob(os.path.join(subdir, "*.csv"))

        for csv_file in csv_files:

            # pula arquivos que já são metadata
            if csv_file.endswith("_metadata.csv"):
                continue

            metadata_path = csv_file.replace(".csv", "_metadata.csv")

            with open(csv_file, "r", encoding="utf-8") as f:
                lines = f.readlines()

            if len(lines) < 3:
                print(f"[IGNORADO] Arquivo pequeno demais: {csv_file}")
                continue

            # --- separar ---
            metadata_lines = lines[:2]      # header + dados do experimento
            training_lines = lines[2:]      # épocas

            # --- salvar metadata ---
            with open(metadata_path, "w", encoding="utf-8") as f:
                f.writelines(metadata_lines)

            # --- sobrescrever o original ---
            with open(csv_file, "w", encoding="utf-8") as f:
                f.writelines(training_lines)

            print(f"[OK] Processado → {os.path.basename(csv_file)}")

def generate_logs_csvs(logs_dir: str = "logs", output_base_dir: str = "logs_csv"):
    process_all_logs_by_epoch(logs_dir, output_base_dir)
    split_csv_metadata_and_logs(output_base_dir)

# %%
generate_logs_csvs("logs", "logs_csv")
# Out:
# Processando logs\densenet121_epochs_100_bs_16_20251120_005412.log...
# CSV salvo em: logs_csv\densenet121\densenet121_epochs_100_bs_16_20251120_005412.csv
# Processando logs\densenet121_epochs_100_bs_16_20251120_043250.log...
# CSV salvo em: logs_csv\densenet121\densenet121_epochs_100_bs_16_20251120_043250.csv
# Processando logs\densenet121_epochs_100_bs_16_20251121_123902.log...
# CSV salvo em: logs_csv\densenet121\densenet121_epochs_100_bs_16_20251121_123902.csv
# Processando logs\densenet121_epochs_100_bs_16_20251126_211102.log...
# CSV salvo em: logs_csv\densenet121\densenet121_epochs_100_bs_16_20251126_211102.csv
# Processando logs\densenet121_epochs_100_bs_16_20251127_002502.log...
# CSV salvo em: logs_csv\densenet121\densenet121_epochs_100_bs_16_20251127_002502.csv
# Processando logs\efficientnet_b0_epochs_100_bs_384_20251122_125216.log...
# CSV salvo em: logs_csv\efficientnet_b0\efficientnet_b0_epochs_100_bs_384_20251122_125216.csv
# ...
